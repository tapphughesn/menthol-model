# %%
import pandas as pd
import numpy as np
from datetime import datetime
import os
from simulation import Simulation
from glob import glob
from matplotlib import pyplot as plt
from matplotlib import ticker

# %%
data_files = sorted(glob('../../outputs/numpy_arrays/*'))
data_files
# Out:
# ['../../outputs/numpy_arrays/np_output_2022-02-23_23-58-48-059270.npy',
#  '../../outputs/numpy_arrays/np_output_2022-02-24_00-00-48-220095.npy']

# %%
arr = np.load(data_files[1])

# %%
arr.shape
# Out:
# (51, 2, 2, 6)

# %%
arr_first_year = arr[0]
arr_first_year.shape
# Out:
# (2, 2, 6)

# %%
# percent non-hispanic black
# and percent all other
# we see 87.8 % nonblack

np.sum(arr_first_year, axis=(1,2)) / np.sum(arr_first_year)
# Out:
# array([0.86914506, 0.13085494])

# %%
# percent smoking states in wave 3

np.sum(arr_first_year, axis=(0,1)) / np.sum(arr_first_year)
# Out:
# array([0.94466103, 0.        , 0.        , 0.        , 0.05533897,
#        0.        ])

# %%
# percent poverty

np.sum(arr_first_year, axis=(0,2)) / np.sum(arr_first_year)
# Out:
# array([0.26612213, 0.73387787])
