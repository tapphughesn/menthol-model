# %%
# !ls ../../data
# Out:
#  age_individual_October21_renamed.xlsx	'age individual_October21.xlsx'

# %%
import pandas as pd
import numpy as np
from dataclasses import dataclass
from datetime import datetime

# %%
now = datetime.now()
print("current time: " + now.strftime("%Y-%m-%d_%H:%M:%S"))
# Out:
# current time: 2021-11-01_21:24:54

# %%
pop_file_name = "../../data/age_individual_October21_renamed.xlsx"
pop_df = pd.read_excel(pop_file_name)

# %%
pop_arr = pop_df.to_numpy()

# %%
np.shape(pop_arr)
# Out:
# (19212, 11)

# %%
pop_arr[0]
# Out:
# array([0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        6.98286028e+03, 1.80000000e+01, 0.00000000e+00])

# %%
class simulation:
    def __init__(self, pop_df, log_reg_params, save_df_filename, num_years=50):
#         self.pop_df = pop_df
        self.pop_arr = pop_df.to_numpy()
        self.num_years=num_years
        self.current_year=0
        self.now_str = datetime.now().strftime("%Y-%m-%d_%H-%M-%S-%f")
        self.log_reg_params = log_reg_params
        self.save_df_filename = save_df_filename
        self.output = np.zeros(num_years, 21)
        
        return
    
    def update():
        """
        Update the smoking status of each person according to transition probabilities
        """
        return 
    
    def writeout():
        """
        blah
        """
        return
