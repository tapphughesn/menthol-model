# %%
import os
import numpy as np
from glob import glob

# %%
dir = "/Users/nick/Documents/Gillings_work/uncertainty_analysis_data/uncertainty_analysis_2023-03-29_14-16-04-931491_UPDATEDMETHOD_April2023/long_term_menthol_ban_parameter_sets/option_3"

# %%
files = sorted(glob(dir + "/*"))
print(len(files))
# Out:
# 100

# %%
sum = np.zeros_like(np.load(files[0]))
for f in files:
    sum += np.load(f)

avg = sum / len(files)

# %%
print(avg)
# Out:
# [0.         0.49889154 0.3998016  0.10130686]
